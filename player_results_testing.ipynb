# %%
import pandas as pd
import numpy as np
import os
import re
import logging

# %%
# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
    handlers=[
        logging.FileHandler("create_player_results_database_all_divisions.log"),
        logging.StreamHandler()
    ]
)

# %%
# Base directory
base_directory = "C:/Users/bpali/PycharmProjects/SquashApp/2024-2025"
current_week = 1
previous_week = 0  # Assuming week 0 has no data

# %%
division = "7A"

# %%
all_divisions = {
    "Premier Main": 424,
    "2": 425,
    "3": 426,
    "4": 427,
    "5": 428,
    "6": 429,
    "7A": 430,
    "7B": 431,
    "8A": 432,
    "8B": 433,
    "9": 434,
    "10": 435,
    "11": 436,
    "12": 437,
    "13A": 438,
    "13B": 439,
    "14": 440,
    "15A": 441,
    "15B": 442,
    "Premier Masters": 443,
    "M2": 444,
    "M3": 445,
    "M4": 446,
    "Premier Ladies": 447,
    "L2": 448,
    "L3": 449,
    "L4": 450,
    }

# %%
def build_player_mapping(all_divisions, base_directory):
    """
    Build a mapping of player names to their divisions and teams across all divisions.

    Args:
        all_divisions (dict): Dictionary of division names and their IDs.
        base_directory (str): Base directory path where player_df files are stored.

    Returns:
        dict: A dictionary mapping player names to their division and team.
    """
    player_mapping = {}
    for division in all_divisions.keys():
        players_df_path = os.path.join(base_directory, "players_df", "week_1", f"{division}_players_df.csv")  # Assuming week 1 has all players
        if not os.path.exists(players_df_path):
            logging.warning(f"Players file for Division {division} not found at {players_df_path}. Skipping.")
            continue
        try:
            players_df = pd.read_csv(players_df_path)
            for _, row in players_df.iterrows():
                player_name = row['Player']
                team = row['Team']
                player_mapping[player_name] = {
                    'Division': division,
                    'Team': team,
                    'Order': row['Order']
                }
        except Exception as e:
            logging.exception(f"Error loading players for Division {division}: {e}")
            continue
    return player_mapping

# %%
# Build the global player mapping
player_mapping = build_player_mapping(all_divisions, base_directory)
logging.info(f"Total players mapped across all divisions: {len(player_mapping)}")
# Out:
# 2024-10-23 17:23:39,106 - INFO - Total players mapped across all divisions: 1679

# %%
def parse_result(result):
    """
    Parse the 'Result' string into overall score and list of rubbers.
    Example result string: '3-2(3-0,2-3,3-1,1-3,3-2)'
    """
    try:
        if '(' in result and ')' in result:
            overall, rubbers_str = result.split('(')
            overall = overall.strip()
            rubbers_str = rubbers_str.strip(')')
            rubbers = rubbers_str.split(',')
            return overall, rubbers
        else:
            # Handle cases where result is not in expected format
            logging.warning(f"Result string '{result}' is not in expected format.")
            return result.strip(), []
    except Exception as e:
        logging.exception(f"Error parsing result string '{result}': {e}")
        return None, []

# %%
def determine_winner(rubber_score, home_team, away_team):
    """
    Determine the winner of a rubber based on the score.

    Args:
        rubber_score (str): Score string, e.g., '3-1', 'CR', 'WO'.
        home_team (str): Name of the home team.
        away_team (str): Name of the away team.

    Returns:
        tuple: (winner_team, conceded_team)
            winner_team: 'Home', 'Away', or 'Draw'
            conceded_team: 'Home', 'Away', or None
    """
    if rubber_score.upper() in ['CR', 'WO']:
        # Without knowing which team conceded, we return 'Undecided' for now
        return 'Undecided', None
    try:
        home_score, away_score = map(int, rubber_score.split('-'))
        if home_score > away_score:
            return 'Home', None
        elif away_score > home_score:
            return 'Away', None
        else:
            return 'Draw', None  # Draws are rare in squash but handled here
    except ValueError as e:
        logging.warning(f"Invalid score format '{rubber_score}' between '{home_team}' and '{away_team}': {e}")
        return 'Unknown', None

# %%
def process_division(division, current_week, previous_week, player_mapping, all_divisions, base_directory):
    """
    Process a division for a given week, handling 'CR', 'WO', 'Playing Up' players, and missing data.

    Args:
        division (str): Division name.
        current_week (int): Current week number.
        previous_week (int): Previous week number.
        player_mapping (dict): Global player mapping.
        all_divisions (dict): Dictionary of division names and their IDs.
        base_directory (str): Base directory path where data files are stored.
    """
    # Construct file paths
    players_df_path = os.path.join(base_directory, "players_df", f"week_{current_week}", f"{division}_players_df.csv")
    schedules_df_path = os.path.join(base_directory, "schedules_df", f"week_{current_week}", f"{division}_schedules_df.csv")
    ranking_df_current_path = os.path.join(base_directory, "ranking_df", f"week_{current_week}", f"{division}_ranking_df.csv")
    ranking_df_previous_path = os.path.join(base_directory, "ranking_df", f"week_{previous_week}", f"{division}_ranking_df.csv")
    
    # Check if current week files exist
    current_files_exist = all([
        os.path.exists(players_df_path),
        os.path.exists(schedules_df_path),
        os.path.exists(ranking_df_current_path)
    ])

    if not current_files_exist:
        logging.warning(f"Data files for Division '{division}' not found for week {current_week}. Skipping.")
        return
    
    # Load the current week's DataFrames
    try:
        players_df = pd.read_csv(players_df_path)
        schedules_df = pd.read_csv(schedules_df_path)
        ranking_df_current = pd.read_csv(ranking_df_current_path)
    except Exception as e:
        logging.exception(f"Error loading data for Division '{division}', Week {current_week}: {e}")
        return
    
    # Filter 'schedules_df' to only include matches from 'current_week'
    if 'Match Week' in schedules_df.columns:
        # Ensure 'Match Week' is of integer type
        schedules_df['Match Week'] = schedules_df['Match Week'].astype(int)
        # Filter matches for the current week
        schedules_df = schedules_df[schedules_df['Match Week'] == current_week]
    else:
        logging.warning(f"'Match Week' column not found in schedules_df for Division '{division}'. Cannot filter by week.")
        return

    # Determine active players based on 'Games Played'
    if current_week == 1:
        # For week 1, players with 'Games Played' == 1 are active
        players_played_this_week = ranking_df_current[ranking_df_current['Games Played'] == 1]['Name of Player']
        active_players = set(players_played_this_week)
    else:
        # For weeks after week 1, compare with previous week's 'Games Played'
        if not os.path.exists(ranking_df_previous_path):
            logging.warning(f"Ranking data for Division '{division}' not found for previous week {previous_week}. Skipping.")
            return
        try:
            ranking_df_previous = pd.read_csv(ranking_df_previous_path)
        except Exception as e:
            logging.exception(f"Error loading previous ranking data for Division '{division}', Week {previous_week}: {e}")
            return

        # Merge current and previous rankings to find players who played this week
        ranking_comparison = ranking_df_current.merge(
            ranking_df_previous[['Name of Player', 'Games Played']],
            on='Name of Player',
            how='left',
            suffixes=('_current', '_previous')
        )
        ranking_comparison['Games Played_previous'] = ranking_comparison['Games Played_previous'].fillna(0)
        ranking_comparison['Games Played_diff'] = ranking_comparison['Games Played_current'] - ranking_comparison['Games Played_previous']
        players_played_this_week = ranking_comparison[ranking_comparison['Games Played_diff'] == 1]['Name of Player']
        active_players = set(players_played_this_week)

    logging.info(f"Number of players who played in Division '{division}' during week {current_week}: {len(active_players)}")

    if not active_players:
        logging.warning(f"No players played in Division '{division}' during week {current_week}. Skipping.")
        return  

    # Create Results DataFrame
    try:
        # Drop unnecessary columns
        schedules_df.drop(columns=['vs', 'Time'], inplace=True, errors='ignore')
    except Exception as e:
        logging.exception(f"Error dropping columns from schedules_df in Division '{division}', Week {current_week}: {e}")
        return

    # Exclude rows where 'Away Team' is '[BYE]' (indicative of a bye week)
    results_df = schedules_df[schedules_df['Away Team'] != '[BYE]'].copy()

    # Replace NaN values in 'Result' with an empty string before applying str.contains
    results_df['Result'] = results_df['Result'].fillna('')

    # Keep rows where 'Result' contains brackets (indicative of a played match)
    results_df = results_df[results_df['Result'].str.contains(r'\(')]

    # Check if results_df is empty
    if results_df.empty:
        logging.info(f"No match results found for Division '{division}' during week {current_week}.")
        return

    # Replace string 'nan' with actual NaN
    results_df['Result'] = results_df['Result'].replace(to_replace=['nan', 'NaN', 'NAN'], value=np.nan)

    # Now, fill NaN with 'Unknown'
    results_df['Result'] = results_df['Result'].fillna('Unknown')

    # Ensure 'Result' is string type
    results_df['Result'] = results_df['Result'].astype(str)

    # Apply the parse_result function to split 'Result' into 'Overall Score' and 'Rubbers'
    try:
        results_df[['Overall Score', 'Rubbers']] = results_df['Result'].apply(lambda x: pd.Series(parse_result(x)))
    except Exception as e:
        logging.exception(f"Error parsing results for Division '{division}', Week {current_week}: {e}")
        return

    # Determine maximum number of rubbers in any match
    max_rubbers = results_df['Rubbers'].apply(lambda x: len(x) if isinstance(x, list) else 0).max()

    # Assign players to each rubber based on 'Order'
    # For each team, get the list of active players and sort them by 'Order'
    team_players = {}
    for team in players_df['Team'].unique():
        # Get active players for the team
        team_data = players_df[(players_df['Team'] == team) & (players_df['Player'].isin(active_players))]
        # Sort active players by 'Order'
        sorted_players = team_data.sort_values('Order')['Player'].tolist()
        team_players[team] = sorted_players

    # Identify 'playing up' players (active_players not in current division's players_df)
    playing_up_players = active_players - set(players_df['Player'])
    logging.info(f"Number of 'Playing Up' players in Division '{division}' during week {current_week}: {len(playing_up_players)}")

    # Ensure 'playing up' players are included in players_df with an 'Order' higher than existing players
    for player in playing_up_players:
        # Get the team the 'playing up' player is playing for
        team = ranking_df_current.loc[ranking_df_current['Name of Player'] == player, 'Team'].values
        if len(team) > 0:
            team = team[0]
        else:
            continue  # Skip if team is not found

        # Find the maximum 'Order' in the team
        team_orders = players_df[players_df['Team'] == team]['Order']
        if not team_orders.empty:
            max_order = team_orders.max()
        else:
            max_order = 0  # If team has no players, start from 0

        # Assign 'Order' as max_order + 1
        order = max_order + 1

        # Check if the player is already in players_df for this team
        if not ((players_df['Player'] == player) & (players_df['Team'] == team)).any():
            # Add the player to players_df
            new_row = {'Player': player, 'Team': team, 'Order': order}
            players_df = pd.concat([players_df, pd.DataFrame([new_row])], ignore_index=True)

    # Prepare active players list for each team, including 'playing up' players
    team_active_players = {}
    for team in players_df['Team'].unique():
        # Get all players for the team
        team_players = players_df[players_df['Team'] == team]['Player'].tolist()
        # Filter active players
        active_team_players = [player for player in team_players if player in active_players]
        team_active_players[team] = active_team_players

    # Process results_df to include rubber details
    try:
        results_df[['Overall Score', 'Rubbers']] = results_df['Result'].apply(
            lambda x: pd.Series(parse_result(x))
        )
    except Exception as e:
        logging.exception(f"Error parsing 'Result' column in Division '{division}', Week {current_week}: {e}")
        return

    # Ensure 'Rubbers' is a list
    results_df['Rubbers'] = results_df['Rubbers'].apply(lambda x: x if isinstance(x, list) else [x])

    # Split the 'Rubbers' list into separate columns
    try:
        for i in range(1, max_rubbers + 1):
            results_df[f'Rubber {i} Score'] = results_df['Rubbers'].apply(
                lambda rubbers: rubbers[i - 1] if i - 1 < len(rubbers) else None
            )
    except Exception as e:
        logging.exception(f"Error extracting 'Rubber {i} Score' in Division '{division}', Week {current_week}: {e}")
        return

    # Process each match and assign players to rubbers
    player_match_results = []
    for idx, row in results_df.iterrows():
        try:
            match_date = row['Date']
            venue = row['Venue']
            home_team = row['Home Team']
            away_team = row['Away Team']
            overall_score = row['Overall Score']
            rubbers = row['Rubbers']
            max_rubbers = len(rubbers)
            
            # Initialize rubber results
            rubber_results = []
            home_rubbers_won = 0
            away_rubbers_won = 0
            undecided_rubbers = []
            
            # First pass: Determine winners of rubbers without 'WO' or 'CR'
            for i in range(1, max_rubbers + 1):
                rubber_score = row.get(f'Rubber {i} Score', None)
                winner_team, conceded_team = determine_winner(rubber_score, home_team, away_team)
                rubber_results.append({
                    'Rubber Number': i,
                    'Rubber Score': rubber_score,
                    'Winner Team': winner_team,
                    'Conceded Team': conceded_team
                })
                if winner_team == 'Home':
                    home_rubbers_won += 1
                elif winner_team == 'Away':
                    away_rubbers_won += 1
                elif winner_team == 'Undecided':
                    undecided_rubbers.append(i)
            
            # Second pass: Resolve 'Undecided' rubbers using overall match score
            try:
                home_match_points, away_match_points = map(int, overall_score.split('-'))
            except Exception as e:
                logging.exception(f"Error parsing 'Overall Score' in match index {idx}: {e}")
                continue  # Skip to the next match
            
            rubbers_needed_by_home = home_match_points - home_rubbers_won
            rubbers_needed_by_away = away_match_points - away_rubbers_won
            
            for rubber in rubber_results:
                if rubber['Winner Team'] == 'Undecided':
                    if rubbers_needed_by_home > 0:
                        rubber['Winner Team'] = 'Home'
                        rubber['Conceded Team'] = 'Away'
                        home_rubbers_won += 1
                        rubbers_needed_by_home -= 1
                    elif rubbers_needed_by_away > 0:
                        rubber['Winner Team'] = 'Away'
                        rubber['Conceded Team'] = 'Home'
                        away_rubbers_won += 1
                        rubbers_needed_by_away -= 1
                    else:
                        rubber['Winner Team'] = 'Unknown'
                        rubber['Conceded Team'] = None
            
            # Get active players for each team, including 'playing up' players
            home_team_players = team_active_players.get(home_team, [])
            away_team_players = team_active_players.get(away_team, [])

            # Sort active players by 'Order'
            home_team_data = players_df[(players_df['Team'] == home_team) & (players_df['Player'].isin(home_team_players))]
            home_team_players_sorted = home_team_data.sort_values('Order')['Player'].tolist()

            away_team_data = players_df[(players_df['Team'] == away_team) & (players_df['Player'].isin(away_team_players))]
            away_team_players_sorted = away_team_data.sort_values('Order')['Player'].tolist()
                        
            # Assign players to rubbers, inserting 'Unknown' where teams have conceded
            # Initialize player indexes
            home_player_idx = 0
            away_player_idx = 0

            # Lists to hold final players assigned to rubbers
            home_players_assigned = []
            away_players_assigned = []

            for rubber in rubber_results:
                winner_team = rubber['Winner Team']
                rubber_score = rubber['Rubber Score']
                
                # Determine if either team conceded
                home_conceded = False
                away_conceded = False
                if rubber_score and rubber_score.upper() in ['CR', 'WO']:
                    if winner_team == 'Home':
                        away_conceded = True  # Away team conceded
                    elif winner_team == 'Away':
                        home_conceded = True  # Home team conceded
                    else:
                        # If winner is 'Unknown' or 'Draw', we cannot determine who conceded
                        pass

                # Assign home player
                if home_conceded:
                    home_players_assigned.append('Unknown')
                else:
                    if home_player_idx < len(home_team_players_sorted):
                        home_players_assigned.append(home_team_players_sorted[home_player_idx])
                        home_player_idx += 1
                    else:
                        home_players_assigned.append('Unknown')

                # Assign away player
                if away_conceded:
                    away_players_assigned.append('Unknown')
                else:
                    if away_player_idx < len(away_team_players_sorted):
                        away_players_assigned.append(away_team_players_sorted[away_player_idx])
                        away_player_idx += 1
                    else:
                        away_players_assigned.append('Unknown')

            # Now, generate player match results
            for idx_rubber, rubber in enumerate(rubber_results):
                i = rubber['Rubber Number']
                rubber_score = rubber['Rubber Score']
                winner_team = rubber['Winner Team']
                home_player = home_players_assigned[idx_rubber]
                away_player = away_players_assigned[idx_rubber]

                if winner_team == 'Home':
                    result_home = 'Win'
                    result_away = 'Loss'
                elif winner_team == 'Away':
                    result_home = 'Loss'
                    result_away = 'Win'
                elif winner_team == 'Draw':
                    result_home = 'Draw'
                    result_away = 'Draw'
                else:
                    result_home = 'Unknown'
                    result_away = 'Unknown'

                # Adjust scores for 'WO' or 'CR' rubbers
                if rubber_score and rubber_score.upper() in ['CR', 'WO']:
                    score_home = rubber_score
                    score_away = rubber_score
                    if winner_team == 'Home':
                        away_player = 'Unknown'  # Away team conceded
                    elif winner_team == 'Away':
                        home_player = 'Unknown'  # Home team conceded
                else:
                    try:
                        home_score, away_score = map(int, rubber_score.split('-'))
                        score_home = f"{home_score}-{away_score}"
                        score_away = f"{away_score}-{home_score}"
                    except (ValueError, TypeError):
                        score_home = rubber_score if rubber_score else 'Unknown'
                        score_away = rubber_score if rubber_score else 'Unknown'

                # Append home player's result
                player_match_results.append({
                    'Player Name': home_player,
                    'Team': home_team,
                    'Opponent Name': away_player,
                    'Opponent Team': away_team,
                    'Match Date': match_date,
                    'Venue': venue,
                    'Rubber Number': i,
                    'Score': score_home,
                    'Result': result_home,
                    'Home/Away': 'Home'
                })

                # Append away player's result
                player_match_results.append({
                    'Player Name': away_player,
                    'Team': away_team,
                    'Opponent Name': home_player,
                    'Opponent Team': home_team,
                    'Match Date': match_date,
                    'Venue': venue,
                    'Rubber Number': i,
                    'Score': score_away,
                    'Result': result_away,
                    'Home/Away': 'Away'
                })

        except Exception as e:
            logging.exception(f"Error processing match at index {idx} in Division '{division}', Week {current_week}: {e}")
            continue  # Skip to the next match


    # Convert the results to a DataFrame
    player_results_df = pd.DataFrame(player_match_results)

    # Reorder columns and handle missing dates
    player_results_df = player_results_df[[
        'Player Name', 'Team', 'Opponent Name', 'Opponent Team', 'Match Date',
        'Venue', 'Rubber Number', 'Score', 'Result', 'Home/Away'
    ]]
    player_results_df['Match Date'] = player_results_df['Match Date'].fillna(pd.NaT)

    # Save the player_results_df
    output_path = os.path.join(
        base_directory,
        "player_results",
        f"week_{current_week}",
        f"{division}_player_results.csv"
    )
    try:
        os.makedirs(os.path.dirname(output_path), exist_ok=True)
        player_results_df.to_csv(output_path, index=False)
        logging.info(f"Player match results saved to {output_path}")
    except Exception as e:
        logging.exception(f"Error saving player results for Division '{division}', Week {current_week}: {e}")
        return

# %%
# Build the global player mapping
player_mapping = build_player_mapping(all_divisions, base_directory)
logging.info(f"Total players mapped across all divisions: {len(player_mapping)}")

# Define week numbers to process
week_numbers = [1, 2, 3]  # Start with week 1

# Define divisions to process
divisions_to_process = ["7A"]  # Test Division 7A

for current_week in week_numbers:
    previous_week = current_week - 1
    for division in all_divisions.keys():
        logging.info(f"Processing Division '{division}' for Week {current_week}")
        try:
            process_division(
                division=division,
                current_week=current_week,
                previous_week=previous_week,
                player_mapping=player_mapping,
                all_divisions=all_divisions,
                base_directory=base_directory
            )
        except Exception as e:
            logging.exception(f"Unexpected error processing Division '{division}', Week {current_week}: {e}")
            continue  # Proceed to the next division
# Out:
# 2024-10-23 17:23:39,295 - INFO - Total players mapped across all divisions: 1679
# 2024-10-23 17:23:39,295 - INFO - Processing Division 'Premier Main' for Week 1
# 2024-10-23 17:23:39,309 - INFO - Number of players who played in Division 'Premier Main' during week 1: 15
# 2024-10-23 17:23:39,309 - INFO - Number of 'Playing Up' players in Division 'Premier Main' during week 1: 1
# 2024-10-23 17:23:39,334 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_1\Premier Main_player_results.csv
# 2024-10-23 17:23:39,335 - INFO - Processing Division '2' for Week 1
# 2024-10-23 17:23:39,343 - INFO - Number of players who played in Division '2' during week 1: 16
# 2024-10-23 17:23:39,350 - INFO - Number of 'Playing Up' players in Division '2' during week 1: 0
# 2024-10-23 17:23:39,360 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_1\2_player_results.csv
# 2024-10-23 17:23:39,361 - INFO - Processing Division '3' for Week 1
# 2024-10-23 17:23:39,367 - INFO - Number of players who played in Division '3' during week 1: 40
# 2024-10-23 17:23:39,382 - INFO - Number of 'Playing Up' players in Division '3' during week 1: 0
# 2024-10-23 17:23:39,396 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_1\3_player_results.csv
# 2024-10-23 17:23:39,398 - INFO - Processing Division '4' for Week 1
# 2024-10-23 17:23:39,404 - INFO - Number of players who played in Division '4' during week 1: 38
# 2024-10-23 17:23:39,417 - INFO - Number of 'Playing Up' players in Division '4' during week 1: 0
# 2024-10-23 17:23:39,431 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_1\4_player_results.csv
# 2024-10-23 17:23:39,431 - INFO - Processing Division '5' for Week 1
# 2024-10-23 17:23:39,434 - INFO - Number of players who played in Division '5' during week 1: 50
# 2024-10-23 17:23:39,451 - INFO - Number of 'Playing Up' players in Division '5' during week 1: 0
# 2024-10-23 17:23:39,467 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_1\5_player_results.csv
# 2024-10-23 17:23:39,467 - INFO - Processing Division '6' for Week 1
# 2024-10-23 17:23:39,467 - INFO - Number of players who played in Division '6' during week 1: 50
# 2024-10-23 17:23:39,483 - INFO - Number of 'Playing Up' players in Division '6' during week 1: 0
# 2024-10-23 17:23:39,500 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_1\6_player_results.csv
# 2024-10-23 17:23:39,500 - INFO - Processing Division '7A' for Week 1
# 2024-10-23 17:23:39,500 - INFO - Number of players who played in Division '7A' during week 1: 28
# 2024-10-23 17:23:39,517 - INFO - Number of 'Playing Up' players in Division '7A' during week 1: 2
# 2024-10-23 17:23:39,533 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_1\7A_player_results.csv
# 2024-10-23 17:23:39,533 - INFO - Processing Division '7B' for Week 1
# 2024-10-23 17:23:39,543 - INFO - Number of players who played in Division '7B' during week 1: 30
# 2024-10-23 17:23:39,550 - INFO - Number of 'Playing Up' players in Division '7B' during week 1: 0
# 2024-10-23 17:23:39,566 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_1\7B_player_results.csv
# 2024-10-23 17:23:39,567 - INFO - Processing Division '8A' for Week 1
# 2024-10-23 17:23:39,573 - INFO - Number of players who played in Division '8A' during week 1: 40
# 2024-10-23 17:23:39,584 - INFO - Number of 'Playing Up' players in Division '8A' during week 1: 1
# 2024-10-23 17:23:39,597 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_1\8A_player_results.csv
# 2024-10-23 17:23:39,597 - INFO - Processing Division '8B' for Week 1
# 2024-10-23 17:23:39,597 - INFO - Number of players who played in Division '8B' during week 1: 39
# 2024-10-23 17:23:39,615 - INFO - Number of 'Playing Up' players in Division '8B' during week 1: 1
# 2024-10-23 17:23:39,630 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_1\8B_player_results.csv
# 2024-10-23 17:23:39,632 - INFO - Processing Division '9' for Week 1
# 2024-10-23 17:23:39,637 - INFO - Number of players who played in Division '9' during week 1: 40
# 2024-10-23 17:23:39,652 - INFO - Number of 'Playing Up' players in Division '9' during week 1: 0
# 2024-10-23 17:23:39,667 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_1\9_player_results.csv
# 2024-10-23 17:23:39,667 - INFO - Processing Division '10' for Week 1
# 2024-10-23 17:23:39,677 - INFO - Number of players who played in Division '10' during week 1: 30
# 2024-10-23 17:23:39,688 - INFO - Number of 'Playing Up' players in Division '10' during week 1: 1
# 2024-10-23 17:23:39,706 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_1\10_player_results.csv
# 2024-10-23 17:23:39,707 - INFO - Processing Division '11' for Week 1
# 2024-10-23 17:23:39,710 - INFO - Number of players who played in Division '11' during week 1: 50
# 2024-10-23 17:23:39,731 - INFO - Number of 'Playing Up' players in Division '11' during week 1: 1
# 2024-10-23 17:23:39,754 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_1\11_player_results.csv
# 2024-10-23 17:23:39,755 - INFO - Processing Division '12' for Week 1
# 2024-10-23 17:23:39,763 - INFO - Number of players who played in Division '12' during week 1: 55
# 2024-10-23 17:23:39,777 - INFO - Number of 'Playing Up' players in Division '12' during week 1: 0
# 2024-10-23 17:23:39,796 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_1\12_player_results.csv
# 2024-10-23 17:23:39,797 - INFO - Processing Division '13A' for Week 1
# 2024-10-23 17:23:39,799 - INFO - Number of players who played in Division '13A' during week 1: 60
# 2024-10-23 17:23:39,812 - INFO - Number of 'Playing Up' players in Division '13A' during week 1: 1
# 2024-10-23 17:23:39,834 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_1\13A_player_results.csv
# 2024-10-23 17:23:39,835 - INFO - Processing Division '13B' for Week 1
# 2024-10-23 17:23:39,841 - INFO - Number of players who played in Division '13B' during week 1: 56
# 2024-10-23 17:23:39,844 - INFO - Number of 'Playing Up' players in Division '13B' during week 1: 2
# 2024-10-23 17:23:39,874 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_1\13B_player_results.csv
# 2024-10-23 17:23:39,875 - INFO - Processing Division '14' for Week 1
# 2024-10-23 17:23:39,885 - INFO - Number of players who played in Division '14' during week 1: 31
# 2024-10-23 17:23:39,893 - INFO - Number of 'Playing Up' players in Division '14' during week 1: 0
# 2024-10-23 17:23:39,900 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_1\14_player_results.csv
# 2024-10-23 17:23:39,900 - INFO - Processing Division '15A' for Week 1
# 2024-10-23 17:23:39,914 - INFO - Number of players who played in Division '15A' during week 1: 28
# 2024-10-23 17:23:39,914 - INFO - Number of 'Playing Up' players in Division '15A' during week 1: 0
# 2024-10-23 17:23:39,928 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_1\15A_player_results.csv
# 2024-10-23 17:23:39,928 - INFO - Processing Division '15B' for Week 1
# 2024-10-23 17:23:39,947 - INFO - Number of players who played in Division '15B' during week 1: 39
# 2024-10-23 17:23:39,954 - INFO - Number of 'Playing Up' players in Division '15B' during week 1: 0
# 2024-10-23 17:23:39,969 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_1\15B_player_results.csv
# 2024-10-23 17:23:39,970 - INFO - Processing Division 'Premier Masters' for Week 1
# 2024-10-23 17:23:39,978 - INFO - Number of players who played in Division 'Premier Masters' during week 1: 6
# 2024-10-23 17:23:39,978 - INFO - Number of 'Playing Up' players in Division 'Premier Masters' during week 1: 0
# 2024-10-23 17:23:39,978 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_1\Premier Masters_player_results.csv
# 2024-10-23 17:23:39,993 - INFO - Processing Division 'M2' for Week 1
# 2024-10-23 17:23:40,002 - INFO - Number of players who played in Division 'M2' during week 1: 24
# 2024-10-23 17:23:40,008 - INFO - Number of 'Playing Up' players in Division 'M2' during week 1: 0
# 2024-10-23 17:23:40,021 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_1\M2_player_results.csv
# 2024-10-23 17:23:40,022 - INFO - Processing Division 'M3' for Week 1
# 2024-10-23 17:23:40,032 - INFO - Number of players who played in Division 'M3' during week 1: 39
# 2024-10-23 17:23:40,032 - INFO - Number of 'Playing Up' players in Division 'M3' during week 1: 1
# 2024-10-23 17:23:40,045 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_1\M3_player_results.csv
# 2024-10-23 17:23:40,045 - INFO - Processing Division 'M4' for Week 1
# 2024-10-23 17:23:40,066 - INFO - Number of players who played in Division 'M4' during week 1: 39
# 2024-10-23 17:23:40,078 - INFO - Number of 'Playing Up' players in Division 'M4' during week 1: 0
# 2024-10-23 17:23:40,082 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_1\M4_player_results.csv
# 2024-10-23 17:23:40,082 - INFO - Processing Division 'Premier Ladies' for Week 1
# 2024-10-23 17:23:40,101 - INFO - Number of players who played in Division 'Premier Ladies' during week 1: 12
# 2024-10-23 17:23:40,107 - INFO - Number of 'Playing Up' players in Division 'Premier Ladies' during week 1: 0
# 2024-10-23 17:23:40,113 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_1\Premier Ladies_player_results.csv
# 2024-10-23 17:23:40,113 - INFO - Processing Division 'L2' for Week 1
# 2024-10-23 17:23:40,113 - INFO - Number of players who played in Division 'L2' during week 1: 24
# 2024-10-23 17:23:40,132 - INFO - Number of 'Playing Up' players in Division 'L2' during week 1: 0
# 2024-10-23 17:23:40,143 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_1\L2_player_results.csv
# 2024-10-23 17:23:40,143 - INFO - Processing Division 'L3' for Week 1
# 2024-10-23 17:23:40,151 - INFO - Number of players who played in Division 'L3' during week 1: 18
# 2024-10-23 17:23:40,160 - INFO - Number of 'Playing Up' players in Division 'L3' during week 1: 2
# 2024-10-23 17:23:40,164 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_1\L3_player_results.csv
# 2024-10-23 17:23:40,176 - INFO - Processing Division 'L4' for Week 1
# 2024-10-23 17:23:40,186 - INFO - Number of players who played in Division 'L4' during week 1: 18
# 2024-10-23 17:23:40,193 - INFO - Number of 'Playing Up' players in Division 'L4' during week 1: 0
# 2024-10-23 17:23:40,205 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_1\L4_player_results.csv
# 2024-10-23 17:23:40,206 - INFO - Processing Division 'Premier Main' for Week 2
# 2024-10-23 17:23:40,215 - INFO - Number of players who played in Division 'Premier Main' during week 2: 13
# 2024-10-23 17:23:40,230 - INFO - Number of 'Playing Up' players in Division 'Premier Main' during week 2: 2
# 2024-10-23 17:23:40,234 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_2\Premier Main_player_results.csv
# 2024-10-23 17:23:40,246 - INFO - Processing Division '2' for Week 2
# 2024-10-23 17:23:40,256 - INFO - Number of players who played in Division '2' during week 2: 16
# 2024-10-23 17:23:40,264 - INFO - Number of 'Playing Up' players in Division '2' during week 2: 0
# 2024-10-23 17:23:40,264 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_2\2_player_results.csv
# 2024-10-23 17:23:40,264 - INFO - Processing Division '3' for Week 2
# 2024-10-23 17:23:40,282 - INFO - Number of players who played in Division '3' during week 2: 39
# 2024-10-23 17:23:40,334 - INFO - Number of 'Playing Up' players in Division '3' during week 2: 1
# 2024-10-23 17:23:40,346 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_2\3_player_results.csv
# 2024-10-23 17:23:40,346 - INFO - Processing Division '4' for Week 2
# 2024-10-23 17:23:40,365 - INFO - Number of players who played in Division '4' during week 2: 39
# 2024-10-23 17:23:40,365 - INFO - Number of 'Playing Up' players in Division '4' during week 2: 1
# 2024-10-23 17:23:40,393 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_2\4_player_results.csv
# 2024-10-23 17:23:40,395 - INFO - Processing Division '5' for Week 2
# 2024-10-23 17:23:40,412 - INFO - Number of players who played in Division '5' during week 2: 20
# 2024-10-23 17:23:40,417 - INFO - Number of 'Playing Up' players in Division '5' during week 2: 1
# 2024-10-23 17:23:40,437 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_2\5_player_results.csv
# 2024-10-23 17:23:40,438 - INFO - Processing Division '6' for Week 2
# 2024-10-23 17:23:40,446 - INFO - Number of players who played in Division '6' during week 2: 50
# 2024-10-23 17:23:40,446 - INFO - Number of 'Playing Up' players in Division '6' during week 2: 0
# 2024-10-23 17:23:40,479 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_2\6_player_results.csv
# 2024-10-23 17:23:40,480 - INFO - Processing Division '7A' for Week 2
# 2024-10-23 17:23:40,493 - INFO - Number of players who played in Division '7A' during week 2: 30
# 2024-10-23 17:23:40,502 - INFO - Number of 'Playing Up' players in Division '7A' during week 2: 0
# 2024-10-23 17:23:40,515 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_2\7A_player_results.csv
# 2024-10-23 17:23:40,516 - INFO - Processing Division '7B' for Week 2
# 2024-10-23 17:23:40,522 - INFO - Number of players who played in Division '7B' during week 2: 30
# 2024-10-23 17:23:40,536 - INFO - Number of 'Playing Up' players in Division '7B' during week 2: 0
# 2024-10-23 17:23:40,550 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_2\7B_player_results.csv
# 2024-10-23 17:23:40,551 - INFO - Processing Division '8A' for Week 2
# 2024-10-23 17:23:40,563 - INFO - Number of players who played in Division '8A' during week 2: 10
# 2024-10-23 17:23:40,573 - INFO - Number of 'Playing Up' players in Division '8A' during week 2: 0
# 2024-10-23 17:23:40,582 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_2\8A_player_results.csv
# 2024-10-23 17:23:40,582 - INFO - Processing Division '8B' for Week 2
# 2024-10-23 17:23:40,597 - INFO - Number of players who played in Division '8B' during week 2: 9
# 2024-10-23 17:23:40,597 - INFO - Number of 'Playing Up' players in Division '8B' during week 2: 1
# 2024-10-23 17:23:40,619 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_2\8B_player_results.csv
# 2024-10-23 17:23:40,619 - INFO - Processing Division '9' for Week 2
# 2024-10-23 17:23:40,632 - INFO - Number of players who played in Division '9' during week 2: 39
# 2024-10-23 17:23:40,639 - INFO - Number of 'Playing Up' players in Division '9' during week 2: 0
# 2024-10-23 17:23:40,650 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_2\9_player_results.csv
# 2024-10-23 17:23:40,650 - INFO - Processing Division '10' for Week 2
# 2024-10-23 17:23:40,677 - INFO - Number of players who played in Division '10' during week 2: 30
# 2024-10-23 17:23:40,682 - INFO - Number of 'Playing Up' players in Division '10' during week 2: 1
# 2024-10-23 17:23:40,710 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_2\10_player_results.csv
# 2024-10-23 17:23:40,713 - INFO - Processing Division '11' for Week 2
# 2024-10-23 17:23:40,730 - INFO - Number of players who played in Division '11' during week 2: 50
# 2024-10-23 17:23:40,745 - INFO - Number of 'Playing Up' players in Division '11' during week 2: 0
# 2024-10-23 17:23:40,761 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_2\11_player_results.csv
# 2024-10-23 17:23:40,761 - INFO - Processing Division '12' for Week 2
# 2024-10-23 17:23:40,780 - INFO - Number of players who played in Division '12' during week 2: 57
# 2024-10-23 17:23:40,807 - INFO - Number of 'Playing Up' players in Division '12' during week 2: 1
# 2024-10-23 17:23:40,827 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_2\12_player_results.csv
# 2024-10-23 17:23:40,827 - INFO - Processing Division '13A' for Week 2
# 2024-10-23 17:23:40,852 - INFO - Number of players who played in Division '13A' during week 2: 39
# 2024-10-23 17:23:40,866 - INFO - Number of 'Playing Up' players in Division '13A' during week 2: 2
# 2024-10-23 17:23:40,887 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_2\13A_player_results.csv
# 2024-10-23 17:23:40,887 - INFO - Processing Division '13B' for Week 2
# 2024-10-23 17:23:40,903 - INFO - Number of players who played in Division '13B' during week 2: 47
# 2024-10-23 17:23:40,911 - INFO - Number of 'Playing Up' players in Division '13B' during week 2: 0
# 2024-10-23 17:23:40,934 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_2\13B_player_results.csv
# 2024-10-23 17:23:40,935 - INFO - Processing Division '14' for Week 2
# 2024-10-23 17:23:40,946 - INFO - Number of players who played in Division '14' during week 2: 36
# 2024-10-23 17:23:40,958 - INFO - Number of 'Playing Up' players in Division '14' during week 2: 0
# 2024-10-23 17:23:40,966 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_2\14_player_results.csv
# 2024-10-23 17:23:40,966 - INFO - Processing Division '15A' for Week 2
# 2024-10-23 17:23:40,985 - INFO - Number of players who played in Division '15A' during week 2: 29
# 2024-10-23 17:23:40,994 - INFO - Number of 'Playing Up' players in Division '15A' during week 2: 0
# 2024-10-23 17:23:41,000 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_2\15A_player_results.csv
# 2024-10-23 17:23:41,000 - INFO - Processing Division '15B' for Week 2
# 2024-10-23 17:23:41,015 - INFO - Number of players who played in Division '15B' during week 2: 38
# 2024-10-23 17:23:41,031 - INFO - Number of 'Playing Up' players in Division '15B' during week 2: 0
# 2024-10-23 17:23:41,031 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_2\15B_player_results.csv
# 2024-10-23 17:23:41,044 - INFO - Processing Division 'Premier Masters' for Week 2
# 2024-10-23 17:23:41,050 - INFO - Number of players who played in Division 'Premier Masters' during week 2: 11
# 2024-10-23 17:23:41,065 - INFO - Number of 'Playing Up' players in Division 'Premier Masters' during week 2: 0
# 2024-10-23 17:23:41,065 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_2\Premier Masters_player_results.csv
# 2024-10-23 17:23:41,065 - INFO - Processing Division 'M2' for Week 2
# 2024-10-23 17:23:41,086 - INFO - Number of players who played in Division 'M2' during week 2: 24
# 2024-10-23 17:23:41,086 - INFO - Number of 'Playing Up' players in Division 'M2' during week 2: 0
# 2024-10-23 17:23:41,104 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_2\M2_player_results.csv
# 2024-10-23 17:23:41,105 - INFO - Processing Division 'M3' for Week 2
# 2024-10-23 17:23:41,118 - INFO - Number of players who played in Division 'M3' during week 2: 40
# 2024-10-23 17:23:41,126 - INFO - Number of 'Playing Up' players in Division 'M3' during week 2: 0
# 2024-10-23 17:23:41,139 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_2\M3_player_results.csv
# 2024-10-23 17:23:41,140 - INFO - Processing Division 'M4' for Week 2
# 2024-10-23 17:23:41,150 - INFO - Number of players who played in Division 'M4' during week 2: 40
# 2024-10-23 17:23:41,161 - INFO - Number of 'Playing Up' players in Division 'M4' during week 2: 0
# 2024-10-23 17:23:41,166 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_2\M4_player_results.csv
# 2024-10-23 17:23:41,166 - INFO - Processing Division 'Premier Ladies' for Week 2
# 2024-10-23 17:23:41,184 - INFO - Number of players who played in Division 'Premier Ladies' during week 2: 12
# 2024-10-23 17:23:41,195 - INFO - Number of 'Playing Up' players in Division 'Premier Ladies' during week 2: 0
# 2024-10-23 17:23:41,201 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_2\Premier Ladies_player_results.csv
# 2024-10-23 17:23:41,201 - INFO - Processing Division 'L2' for Week 2
# 2024-10-23 17:23:41,221 - INFO - Number of players who played in Division 'L2' during week 2: 24
# 2024-10-23 17:23:41,233 - INFO - Number of 'Playing Up' players in Division 'L2' during week 2: 0
# 2024-10-23 17:23:41,242 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_2\L2_player_results.csv
# 2024-10-23 17:23:41,243 - INFO - Processing Division 'L3' for Week 2
# 2024-10-23 17:23:41,256 - INFO - Number of players who played in Division 'L3' during week 2: 18
# 2024-10-23 17:23:41,264 - INFO - Number of 'Playing Up' players in Division 'L3' during week 2: 1
# 2024-10-23 17:23:41,276 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_2\L3_player_results.csv
# 2024-10-23 17:23:41,278 - INFO - Processing Division 'L4' for Week 2
# 2024-10-23 17:23:41,278 - INFO - Number of players who played in Division 'L4' during week 2: 14
# 2024-10-23 17:23:41,297 - INFO - Number of 'Playing Up' players in Division 'L4' during week 2: 0
# 2024-10-23 17:23:41,297 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_2\L4_player_results.csv
# 2024-10-23 17:23:41,311 - INFO - Processing Division 'Premier Main' for Week 3
# 2024-10-23 17:23:41,313 - WARNING - Data files for Division 'Premier Main' not found for week 3. Skipping.
# 2024-10-23 17:23:41,314 - INFO - Processing Division '2' for Week 3
# 2024-10-23 17:23:41,314 - INFO - Number of players who played in Division '2' during week 3: 8
# 2024-10-23 17:23:41,333 - INFO - Number of 'Playing Up' players in Division '2' during week 3: 0
# 2024-10-23 17:23:41,337 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_3\2_player_results.csv
# 2024-10-23 17:23:41,337 - INFO - Processing Division '3' for Week 3
# 2024-10-23 17:23:41,337 - WARNING - Data files for Division '3' not found for week 3. Skipping.
# 2024-10-23 17:23:41,337 - INFO - Processing Division '4' for Week 3
# 2024-10-23 17:23:41,337 - WARNING - Data files for Division '4' not found for week 3. Skipping.
# 2024-10-23 17:23:41,337 - INFO - Processing Division '5' for Week 3
# 2024-10-23 17:23:41,346 - WARNING - Data files for Division '5' not found for week 3. Skipping.
# 2024-10-23 17:23:41,347 - INFO - Processing Division '6' for Week 3
# 2024-10-23 17:23:41,351 - INFO - Number of players who played in Division '6' during week 3: 40
# 2024-10-23 17:23:41,367 - INFO - Number of 'Playing Up' players in Division '6' during week 3: 0
# 2024-10-23 17:23:41,383 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_3\6_player_results.csv
# 2024-10-23 17:23:41,383 - INFO - Processing Division '7A' for Week 3
# 2024-10-23 17:23:41,402 - INFO - Number of players who played in Division '7A' during week 3: 30
# 2024-10-23 17:23:41,403 - INFO - Number of 'Playing Up' players in Division '7A' during week 3: 1
# 2024-10-23 17:23:41,424 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_3\7A_player_results.csv
# 2024-10-23 17:23:41,425 - INFO - Processing Division '7B' for Week 3
# 2024-10-23 17:23:41,439 - INFO - Number of players who played in Division '7B' during week 3: 30
# 2024-10-23 17:23:41,449 - INFO - Number of 'Playing Up' players in Division '7B' during week 3: 0
# 2024-10-23 17:23:41,450 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_3\7B_player_results.csv
# 2024-10-23 17:23:41,450 - INFO - Processing Division '8A' for Week 3
# 2024-10-23 17:23:41,462 - WARNING - Data files for Division '8A' not found for week 3. Skipping.
# 2024-10-23 17:23:41,464 - INFO - Processing Division '8B' for Week 3
# 2024-10-23 17:23:41,464 - WARNING - Data files for Division '8B' not found for week 3. Skipping.
# 2024-10-23 17:23:41,465 - INFO - Processing Division '9' for Week 3
# 2024-10-23 17:23:41,475 - INFO - Number of players who played in Division '9' during week 3: 40
# 2024-10-23 17:23:41,486 - INFO - Number of 'Playing Up' players in Division '9' during week 3: 1
# 2024-10-23 17:23:41,502 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_3\9_player_results.csv
# 2024-10-23 17:23:41,502 - INFO - Processing Division '10' for Week 3
# 2024-10-23 17:23:41,516 - INFO - Number of players who played in Division '10' during week 3: 20
# 2024-10-23 17:23:41,528 - INFO - Number of 'Playing Up' players in Division '10' during week 3: 0
# 2024-10-23 17:23:41,541 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_3\10_player_results.csv
# 2024-10-23 17:23:41,542 - INFO - Processing Division '11' for Week 3
# 2024-10-23 17:23:41,543 - WARNING - Data files for Division '11' not found for week 3. Skipping.
# 2024-10-23 17:23:41,543 - INFO - Processing Division '12' for Week 3
# 2024-10-23 17:23:41,555 - INFO - Number of players who played in Division '12' during week 3: 57
# 2024-10-23 17:23:41,568 - INFO - Number of 'Playing Up' players in Division '12' during week 3: 1
# 2024-10-23 17:23:41,587 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_3\12_player_results.csv
# 2024-10-23 17:23:41,594 - INFO - Processing Division '13A' for Week 3
# 2024-10-23 17:23:41,597 - WARNING - Data files for Division '13A' not found for week 3. Skipping.
# 2024-10-23 17:23:41,598 - INFO - Processing Division '13B' for Week 3
# 2024-10-23 17:23:41,599 - WARNING - Data files for Division '13B' not found for week 3. Skipping.
# 2024-10-23 17:23:41,600 - INFO - Processing Division '14' for Week 3
# 2024-10-23 17:23:41,611 - INFO - Number of players who played in Division '14' during week 3: 39
# 2024-10-23 17:23:41,623 - INFO - Number of 'Playing Up' players in Division '14' during week 3: 0
# 2024-10-23 17:23:41,636 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_3\14_player_results.csv
# 2024-10-23 17:23:41,646 - INFO - Processing Division '15A' for Week 3
# 2024-10-23 17:23:41,658 - INFO - Number of players who played in Division '15A' during week 3: 19
# 2024-10-23 17:23:41,661 - INFO - Number of 'Playing Up' players in Division '15A' during week 3: 0
# 2024-10-23 17:23:41,676 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_3\15A_player_results.csv
# 2024-10-23 17:23:41,681 - INFO - Processing Division '15B' for Week 3
# 2024-10-23 17:23:41,698 - INFO - Number of players who played in Division '15B' during week 3: 30
# 2024-10-23 17:23:41,702 - INFO - Number of 'Playing Up' players in Division '15B' during week 3: 0
# 2024-10-23 17:23:41,735 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_3\15B_player_results.csv
# 2024-10-23 17:23:41,736 - INFO - Processing Division 'Premier Masters' for Week 3
# 2024-10-23 17:23:41,749 - INFO - Number of players who played in Division 'Premier Masters' during week 3: 12
# 2024-10-23 17:23:41,755 - INFO - Number of 'Playing Up' players in Division 'Premier Masters' during week 3: 1
# 2024-10-23 17:23:41,770 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_3\Premier Masters_player_results.csv
# 2024-10-23 17:23:41,771 - INFO - Processing Division 'M2' for Week 3
# 2024-10-23 17:23:41,787 - INFO - Number of players who played in Division 'M2' during week 3: 24
# 2024-10-23 17:23:41,800 - INFO - Number of 'Playing Up' players in Division 'M2' during week 3: 0
# 2024-10-23 17:23:41,802 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_3\M2_player_results.csv
# 2024-10-23 17:23:41,802 - INFO - Processing Division 'M3' for Week 3
# 2024-10-23 17:23:41,862 - INFO - Number of players who played in Division 'M3' during week 3: 30
# 2024-10-23 17:23:41,877 - INFO - Number of 'Playing Up' players in Division 'M3' during week 3: 0
# 2024-10-23 17:23:41,905 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_3\M3_player_results.csv
# 2024-10-23 17:23:41,908 - INFO - Processing Division 'M4' for Week 3
# 2024-10-23 17:23:41,926 - INFO - Number of players who played in Division 'M4' during week 3: 40
# 2024-10-23 17:23:41,931 - INFO - Number of 'Playing Up' players in Division 'M4' during week 3: 0
# 2024-10-23 17:23:41,950 - INFO - Player match results saved to C:/Users/bpali/PycharmProjects/SquashApp/2024-2025\player_results\week_3\M4_player_results.csv
# 2024-10-23 17:23:41,950 - INFO - Processing Division 'Premier Ladies' for Week 3
# 2024-10-23 17:23:41,950 - WARNING - Data files for Division 'Premier Ladies' not found for week 3. Skipping.
# 2024-10-23 17:23:41,950 - INFO - Processing Division 'L2' for Week 3
# 2024-10-23 17:23:41,950 - WARNING - Data files for Division 'L2' not found for week 3. Skipping.
# 2024-10-23 17:23:41,950 - INFO - Processing Division 'L3' for Week 3
# 2024-10-23 17:23:41,950 - WARNING - Data files for Division 'L3' not found for week 3. Skipping.
# 2024-10-23 17:23:41,950 - INFO - Processing Division 'L4' for Week 3
# 2024-10-23 17:23:41,950 - WARNING - Data files for Division 'L4' not found for week 3. Skipping.
